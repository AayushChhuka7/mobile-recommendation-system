# %%
import pandas as pd

# %%
oppo=pd.read_csv("Oppo.csv")
vivo=pd.read_csv("Vivo.csv")
realme=pd.read_csv("Realme.csv")
xiaomi=pd.read_csv("Xiaomi.csv")

# %%
GSMArena_BATCH3=pd.concat([oppo,vivo,realme ,xiaomi] , axis=0)
GSMArena_BATCH3
# Out:
#       Brand               Model_Name  \
# 0      Oppo  Oppo Reno16 Pro (China)
# 1      Oppo      Oppo Reno16 (China)
# 2      Oppo               Oppo Pad 6
# 3      Oppo               Oppo Pad 6
# 4      Oppo       Oppo Find X9 Ultra
# ..      ...                      ...
# 516  Xiaomi      Xiaomi Mi Max 4 Pro
# 517  Xiaomi          Xiaomi Mi Max 4
# 518  Xiaomi             Xiaomi Mi 6c
# 519  Xiaomi       Xiaomi Redmi Pro 2
# 520  Xiaomi      Xiaomi Mi Note Plus
#
#                                              Model_URL  \
# 0    https://www.gsmarena.com/oppo_reno16_pro_5g_(c...
# 1    https://www.gsmarena.com/oppo_reno16_5g_(china...
# 2        https://www.gsmarena.com/oppo_pad_6-14690.php
# 3        https://www.gsmarena.com/oppo_pad_6-14690.php
# 4    https://www.gsmarena.com/oppo_find_x9_ultra_5g...
# ..                                                 ...
# 516  https://www.gsmarena.com/xiaomi_mi_max_4_pro-9...
# 517  https://www.gsmarena.com/xiaomi_mi_max_4-9551.php
# ...

# %%
GSMArena_BATCH3.isnull().mean()
# Out:
# Brand                 0.000000
# Model_Name            0.000000
# Model_URL             0.000000
# Model_Image           0.000000
# Network_Technology    0.000000
#                         ...
# Colors                0.000000
# Model_Numbers         0.215983
# SAR_US                0.804536
# SAR_EU                0.896328
# FM_Radio              0.003240
# Length: 68, dtype: float64

# %%
GSMArena_BATCH3["Brand"].unique()
# Out:
# array(['Oppo', 'Vivo', 'Realme', 'Xiaomi'], dtype=object)

# %%
GSMArena_BATCH3.to_csv("GSMArena_BATCH3.csv" , index=False)
